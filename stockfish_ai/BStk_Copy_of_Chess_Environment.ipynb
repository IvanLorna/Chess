# %%
# !pip install stockfish
# !chmod +x /content/stockfish/stockfish
# !pip install python-chess==0.31.3
# Out:
# Requirement already satisfied: stockfish in /usr/local/lib/python3.7/dist-packages (3.15.0)
# Requirement already satisfied: python-chess==0.31.3 in /usr/local/lib/python3.7/dist-packages (0.31.3)

# %%
#import libraries
import chess
import chess.engine
import numpy as np
from stockfish import Stockfish
from Agent import Agent
from Environment import Environement
from dataload import DataLoad
from stkfish import Stkfish

# %%
# White = Agent(isWhite = True)
# Black = Stkfish(isWhite = False)
# Game = Environement(White, Black)

# Game.Training(25)

# print(Game.Winner)
# Game.board

# %%
White = Agent(isWhite = True)
Black = Stkfish(isWhite = False)
Game = Environement(White, Black)

Game.Training(25)

print(Game.Winner)
Game.board
# Out:
# ELO for White: 1000 ELO for Black: 1000
# The Winner is: Black
# Decisive Move: b2c2
# ELO for White: 987.5 ELO for Black: 1012.5
# The Winner is: Black
# Decisive Move: d8d2
# ELO for White: 974.1021018263724 ELO for Black: 1025.8978981736275
# The Winner is: Black
# Decisive Move: d2d1
# ELO for White: 959.752282032871 ELO for Black: 1040.247717967129
# The Winner is: Black
# Decisive Move: f8b4
# ELO for White: 944.4069548774982 ELO for Black: 1055.5930451225017
# The Winner is: Black
# Decisive Move: f2d2
# ELO for White: 928.0379003095996 ELO for Black: 1071.9620996904002
# The Winner is: Black
# Decisive Move: d8d2
# ELO for White: 910.6369887777504 ELO for Black: 1089.3630112222495
# The Winner is: Black
# Decisive Move: c6d4
# ELO for White: 892.21976519151 ELO for Black: 1107.78023480849
# The Winner is: Black
# Decisive Move: c2c1
# ELO for White: 872.8268980648905 ELO for Black: 1127.1731019351093
# The Winner is: Black
# Decisive Move: h8h5
# ELO for White: 852.5227927437827 ELO for Black: 1147.4772072562173
# The Winner is: Black
# Decisive Move: e3c4
# ELO for White: 831.3913054580843 ELO for Black: 1168.6086945419158
# The Winner is: Black
# Decisive Move: c5f2
# ELO for White: 809.529264248668 ELO for Black: 1190.470735751332
# The Winner is: Black
# Decisive Move: d8d1
# ELO for White: 787.0390669718811 ELO for Black: 1212.960933028119
# The Winner is: Black
# Decisive Move: e3d3
# ELO for White: 764.0217363154541 ELO for Black: 1235.978263684546
# The Winner is: Black
# Decisive Move: b4d2
# ELO for White: 740.5714679512954 ELO for Black: 1259.4285320487047
# The Winner is: Black
# Decisive Move: d3d1
# ELO for White: 716.7721337698905 ELO for Black: 1283.2278662301096
# The Winner is: Black
# Decisive Move: a8c8
# ELO for White: 692.6956688362354 ELO for Black: 1307.3043311637648
# The Winner is: Black
# Decisive Move: d3d1
# ELO for White: 668.401941657656 ELO for Black: 1331.5980583423443
# The Winner is: Black
# Decisive Move: d4d3
# ELO for White: 643.9396016318306 ELO for Black: 1356.06039836817
# The Winner is: Black
# Decisive Move: d8d1
# ELO for White: 619.3474461266981 ELO for Black: 1380.6525538733024
# The Winner is: Black
# Decisive Move: d3d1
# ELO for White: 594.655966849471 ELO for Black: 1405.3440331505294
# The Winner is: Black
# Decisive Move: e2e1q
# ELO for White: 569.8888591478882 ELO for Black: 1430.1111408521122
# The Winner is: Black
# Decisive Move: c5f2
# ELO for White: 545.0643782832938 ELO for Black: 1454.9356217167065
# The Winner is: Black
# Decisive Move: c1d1
# ELO for White: 520.196495889493 ELO for Black: 1479.8035041105072
# The Winner is: Black
# Decisive Move: h1f1
# ELO for White: 495.29585165250023 ELO for Black: 1504.7041483475
# The Winner is: Black
# Decisive Move: g2g3
# Black
# Board('r2q2k1/pp3ppp/2p5/8/3P1P2/4nbr1/PP1B3P/R6K w - - 1 22')

# %%
Game.Training(25)

print(Game.Winner)
Game.board
# Out:
# ELO for White: 470.3705171997824 ELO for Black: 1529.6294828002178
# The Winner is: Black
# Decisive Move: c1d1
# ELO for White: 445.4265983961996 ELO for Black: 1554.5734016038007
# The Winner is: Black
# Decisive Move: g4e4
# ELO for White: 420.4687041001919 ELO for Black: 1579.5312958998084
# The Winner is: Black
# Decisive Move: a2c3
# ELO for White: 395.5003075268347 ELO for Black: 1604.4996924731656
# The Winner is: Black
# Decisive Move: a8a1
# ELO for White: 370.5240228678025 ELO for Black: 1629.4759771321978
# The Winner is: Black
# Decisive Move: c5b4
# ELO for White: 345.54181593896345 ELO for Black: 1654.458184061037
# The Winner is: Black
# Decisive Move: e2f4
# ELO for White: 320.55516396814454 ELO for Black: 1679.4448360318559
# The Winner is: Black
# Decisive Move: c8b7
# ELO for White: 295.5651764526959 ELO for Black: 1704.4348235473046
# The Winner is: Black
# Decisive Move: d3c2
# ELO for White: 270.5726863744244 ELO for Black: 1729.427313625576
# The Winner is: Black
# Decisive Move: d5d1
# ELO for White: 245.5783189312509 ELO for Black: 1754.4216810687496
# The Winner is: Black
# Decisive Move: a4a1
# ELO for White: 220.58254326490314 ELO for Black: 1779.4174567350974
# The Winner is: Black
# Decisive Move: g1c1
# ELO for White: 195.58571135618317 ELO for Black: 1804.4142886438174
# The Winner is: Black
# Decisive Move: f4g4
# ELO for White: 170.58808725143695 ELO for Black: 1829.4119127485635
# The Winner is: Black
# Decisive Move: f3d3
# ELO for White: 145.58986901261252 ELO for Black: 1854.410130987388
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: 120.59120519622546 ELO for Black: 1879.408794803775
# The Winner is: Black
# Decisive Move: d4d2
# ELO for White: 95.59220722138755 ELO for Black: 1904.407792778613
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: 70.59295865045519 ELO for Black: 1929.4070413495454
# The Winner is: Black
# Decisive Move: c2d1q
# ELO for White: 45.5935221518726 ELO for Black: 1954.406477848128
# The Winner is: Black
# Decisive Move: d2f2
# ELO for White: 20.593944723446057 ELO for Black: 1979.4060552765545
# The Winner is: Black
# Decisive Move: d2e3
# ELO for White: -4.405738389696705 ELO for Black: 2004.4057383896973
# The Winner is: Black
# Decisive Move: d4d2
# ELO for White: -29.405500756457158 ELO for Black: 2029.4055007564577
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: -54.4053225557557 ELO for Black: 2054.4053225557564
# The Winner is: Black
# Decisive Move: c1e2
# ELO for White: -79.4051889235692 ELO for Black: 2079.4051889235698
# The Winner is: Black
# Decisive Move: a5d2
# ELO for White: -104.40508871327822 ELO for Black: 2104.405088713279
# The Winner is: Black
# Decisive Move: g4f4
# ELO for White: -129.40501356599927 ELO for Black: 2129.405013566
# The Winner is: Black
# Decisive Move: f6e4
# Black
# Board('rnb1k2r/pp3ppp/2p1p3/8/P1q1n3/4B3/3K1P1P/R4q2 w kq - 2 16')

# %%
Game.Training(25)

print(Game.Winner)
Game.board
# Out:
# ELO for White: -154.4049572133988 ELO for Black: 2154.4049572133995
# The Winner is: Black
# Decisive Move: d4d1
# ELO for White: -179.40491495485878 ELO for Black: 2179.4049149548596
# The Winner is: Black
# Decisive Move: e4d4
# ELO for White: -204.4048832653955 ELO for Black: 2204.404883265396
# The Winner is: Black
# Decisive Move: g4f2
# ELO for White: -229.40485950163432 ELO for Black: 2229.4048595016347
# The Winner is: Black
# Decisive Move: e2c2
# ELO for White: -254.4048416813183 ELO for Black: 2254.404841681319
# Stalemate Due to Repetition
# ELO for White: -266.90482831796135 ELO for Black: 2266.904828317962
# The Winner is: Black
# Decisive Move: g7h8q
# ELO for White: -291.9048167457684 ELO for Black: 2291.904816745769
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: -316.90480806784575 ELO for Black: 2316.9048080678463
# The Winner is: Black
# Decisive Move: a4d1
# ELO for White: -341.9048015603206 ELO for Black: 2341.904801560321
# The Winner is: Black
# Decisive Move: h5h2
# ELO for White: -366.9047966803645 ELO for Black: 2366.904796680365
# The Winner is: Black
# Decisive Move: b8c6
# ELO for White: -391.90479302091325 ELO for Black: 2391.904793020914
# The Winner is: Black
# Decisive Move: f8b4
# ELO for White: -416.90479027671176 ELO for Black: 2416.9047902767124
# The Winner is: Black
# Decisive Move: d4d2
# ELO for White: -441.90478821885085 ELO for Black: 2441.9047882188515
# The Winner is: Black
# Decisive Move: a1c1
# ELO for White: -466.90478667567277 ELO for Black: 2466.9047866756737
# The Winner is: Black
# Decisive Move: c4a3
# ELO for White: -491.90478551845246 ELO for Black: 2491.9047855184535
# The Winner is: Black
# Decisive Move: e2c2
# ELO for White: -516.9047846506596 ELO for Black: 2516.9047846506605
# The Winner is: Black
# Decisive Move: d1e1
# ELO for White: -541.9047839999067 ELO for Black: 2541.9047839999075
# The Winner is: Black
# Decisive Move: d1e1
# ELO for White: -566.904783511911 ELO for Black: 2566.904783511912
# The Winner is: Black
# Decisive Move: f2d2
# ELO for White: -591.9047831459658 ELO for Black: 2591.9047831459666
# The Winner is: Black
# Decisive Move: d2f3
# ELO for White: -616.9047828715455 ELO for Black: 2616.9047828715466
# The Winner is: Black
# Decisive Move: d2d1
# ELO for White: -641.9047826657594 ELO for Black: 2641.9047826657606
# The Winner is: Black
# Decisive Move: e7b4
# ELO for White: -666.9047825114416 ELO for Black: 2666.904782511443
# The Winner is: Black
# Decisive Move: e4d3
# ELO for White: -691.9047823957195 ELO for Black: 2691.904782395721
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: -716.9047823089402 ELO for Black: 2716.904782308942
# The Winner is: Black
# Decisive Move: c1f1
# ELO for White: -741.9047822438649 ELO for Black: 2741.9047822438665
# The Winner is: Black
# Decisive Move: e4e2
# Black
# Board('rn2k2r/ppp2ppp/4pn2/8/PbpP2PP/5b2/3NqPB1/R1B1K2R w KQkq - 0 12')

# %%
Game.Training(25)

print(Game.Winner)
Game.board
# Out:
# ELO for White: -766.9047821950653 ELO for Black: 2766.904782195067
# The Winner is: Black
# Decisive Move: d3b3
# ELO for White: -791.9047821584708 ELO for Black: 2791.9047821584727
# The Winner is: Black
# Decisive Move: f1d3
# ELO for White: -816.9047821310287 ELO for Black: 2816.9047821310305
# The Winner is: Black
# Decisive Move: f1e3
# ELO for White: -841.9047821104501 ELO for Black: 2841.904782110452
# The Winner is: Black
# Decisive Move: e3d2
# ELO for White: -866.9047820950184 ELO for Black: 2866.90478209502
# The Winner is: Black
# Decisive Move: h3g2
# ELO for White: -891.9047820834462 ELO for Black: 2891.9047820834476
# The Winner is: Black
# Decisive Move: g4f2
# ELO for White: -916.9047820747683 ELO for Black: 2916.9047820747696
# The Winner is: Black
# Decisive Move: f5g4
# ELO for White: -941.9047820682607 ELO for Black: 2941.904782068262
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: -966.9047820633807 ELO for Black: 2966.9047820633823
# The Winner is: Black
# Decisive Move: h4f2
# ELO for White: -991.9047820597212 ELO for Black: 2991.904782059723
# The Winner is: Black
# Decisive Move: e3d2
# ELO for White: -1016.9047820569771 ELO for Black: 3016.9047820569785
# The Winner is: Black
# Decisive Move: h4f2
# ELO for White: -1041.9047820549192 ELO for Black: 3041.904782054921
# The Winner is: Black
# Decisive Move: h4f2
# ELO for White: -1066.904782053376 ELO for Black: 3066.904782053378
# The Winner is: Black
# Decisive Move: g2h1q
# ELO for White: -1091.9047820522187 ELO for Black: 3091.9047820522205
# The Winner is: Black
# Decisive Move: c1c2
# ELO for White: -1116.9047820513508 ELO for Black: 3116.904782051353
# The Winner is: Black
# Decisive Move: f8b4
# ELO for White: -1141.9047820507 ELO for Black: 3141.904782050702
# The Winner is: Black
# Decisive Move: f6e4
# ELO for White: -1166.9047820502121 ELO for Black: 3166.904782050214
# The Winner is: Black
# Decisive Move: h4f2
# ELO for White: -1191.9047820498463 ELO for Black: 3191.904782049848
# The Winner is: Black
# Decisive Move: d5g2
# ELO for White: -1216.9047820495718 ELO for Black: 3216.904782049574
# The Winner is: Black
# Decisive Move: b4d2
# ELO for White: -1241.904782049366 ELO for Black: 3241.904782049368
# The Winner is: Black
# Decisive Move: d1f3
# ELO for White: -1266.9047820492117 ELO for Black: 3266.9047820492137
# The Winner is: Black
# Decisive Move: f5f2
# ELO for White: -1291.904782049096 ELO for Black: 3291.9047820490982
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: -1316.904782049009 ELO for Black: 3316.9047820490114
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: -1341.904782048944 ELO for Black: 3341.9047820489463
# The Winner is: Black
# Decisive Move: h4h2
# ELO for White: -1366.9047820488952 ELO for Black: 3366.9047820488977
# The Winner is: Black
# Decisive Move: h4h3
# Black
# Board('rnb1k2r/pp3ppp/4p3/P5PP/8/7q/3bn3/5R1K w kq - 0 23')

# %%
# print("ELO for White:",Game.R_White,"ELO for Black",Game.R_Black)

# %%
# import matplotlib.pyplot as plt
# ELO_White = [1000,1000,1000,1000,1000,1012.5,1013.397898,1014.360048,1015.390989,1016.495571,1017.678968,1018.946698,1020.304643,1021.759062,1023.316616,1024.984378,1026.769855,1028.680997,1030.726211,1032.914368,1035.254808,1037.757333,1040.432203,1043.290114,1046.342171,1049.599845,1053.074919,1056.779413,1060.725491,1064.925351,1069.391089,1074.134538,1079.167087,1084.49948,1090.141591,1096.102191,1102.388706,1096.506977,1102.815226,1109.455554,1116.431868,1123.746054,1131.397827,1139.384623,1147.701566,1156.341492,1165.295057,1174.550908,1184.09592,1193.91548,1203.993813,1214.314316,1224.859904,1235.613328,1246.557478,1257.675635,1268.951691,1280.370312,1291.917067,1303.5785,1315.342184,1327.196725,1339.13175,1351.137876,1363.206661,1375.330543,1387.502784,1399.717393,1411.969069,1424.253132,1436.565459,1448.902428,1461.260861,1473.637977,1486.031343,1498.438837,1510.858604,1523.289032,1535.728714,1548.176428,1560.63111,1573.091836,1585.557804,1598.028317,1610.502769,1622.980636,1635.461462,1647.944853,1660.430466,1672.918005,1685.407211,1697.897863,1710.389766,1722.882754,1735.37668,1747.871421,1760.366865,1772.862921,1785.359504,1797.856546]
# ELO_Black = [1000,1000,1000,1000,1000,987.5,986.6021018,985.6399525,984.6090111,983.5044291,982.321032,981.0533015,979.6953571,978.2409378,976.6833844,975.0156221,973.2301453,971.3190033,969.2737891,967.0856315,964.745192,962.2426669,959.567797,956.709886,953.6578291,950.4001547,946.9250807,943.2205874,939.2745093,935.0746488,930.6089109,925.8654624,920.8329133,915.5005204,909.8584091,903.8978086,897.6112937,903.4930234,897.1847744,890.5444458,883.568132,876.2539456,868.602173,860.6153765,852.2984339,843.658508,834.704943,825.449092,815.9040805,806.0845201,796.0061874,785.6856838,775.1400962,764.3866718,753.4425223,742.324365,731.0483092,719.6296876,708.0829335,696.4214997,684.6578157,672.8032752,660.8682501,648.8621239,636.7933393,624.6694565,612.4972164,600.2826072,588.0309306,575.7468676,563.4345406,551.097572,538.7391389,526.362023,513.9686565,501.5611633,489.1413957,476.710968,464.2712859,451.8235721,439.36889,426.9081637,414.4421958,401.9716833,389.4972312,377.0193642,364.5385378,352.0551469,339.5695337,327.0819952,314.5927887,302.1021372,289.610234,277.1172464,264.6233197,252.1285794,239.6331346,227.1370795,214.6404959,202.1434545]
# fig, ax = plt.subplots()
# ax.plot(ELO_White, color = 'blue', label = 'ELO score for White')
# ax.plot(ELO_Black, color = 'black', label = 'ELO score for Black')
# plt.xlabel("Number of Games")
# plt.ylabel("ELO Rating")
# plt.legend()
# plt.show()
