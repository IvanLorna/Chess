# %%
# !pip install stockfish
# !chmod +x /content/stockfish/stockfish
# !pip install python-chess==0.31.3
# Out:
# Requirement already satisfied: stockfish in /usr/local/lib/python3.7/dist-packages (3.15.0)
# Requirement already satisfied: python-chess==0.31.3 in /usr/local/lib/python3.7/dist-packages (0.31.3)

# %%
import chess
import chess.engine
import numpy as np
import time
from stockfish import Stockfish
from Agent import Agent
from Greedy import Greedy
from Environment import Environement
from dataload import DataLoad

# %%
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60.
    return '{}:{:>02}:{:>05.2f}'.format(h, m, s)

# %%
White = Agent(isWhite=True)
Black = Greedy(isWhite=False)

Game = Environement(White, Black)
start_time = time.time()
Game.Training(25)

elapsed_time = time.time() - start_time
print("Elapsed time: {}".format(hms_string(elapsed_time)))
print("1st Quarter Winner: {}".format(Game.Winner))
Game.board
# Out:
# ELO for White: 1000 ELO for Black: 1000
# The Winner is: Black
# Decisive Move: d4c2
# ELO for White: 987.5 ELO for Black: 1012.5
# The Winner is: Black
# Decisive Move: d5g2
# ELO for White: 974.1021018263724 ELO for Black: 1025.8978981736275
# The Winner is: Black
# Decisive Move: a2a1q
# ELO for White: 959.752282032871 ELO for Black: 1040.247717967129
# The Winner is: Black
# Decisive Move: d2d1
# ELO for White: 944.4069548774982 ELO for Black: 1055.5930451225017
# The Winner is: Black
# Decisive Move: h2h1q
# ELO for White: 928.0379003095996 ELO for Black: 1071.9620996904002
# The Winner is: Black
# Decisive Move: d8d1
# ELO for White: 910.6369887777504 ELO for Black: 1089.3630112222495
# The Winner is: Black
# Decisive Move: c2c1q
# ELO for White: 892.21976519151 ELO for Black: 1107.78023480849
# The Winner is: Black
# Decisive Move: e2e1q
# ELO for White: 872.8268980648905 ELO for Black: 1127.1731019351093
# The Winner is: Black
# Decisive Move: d3c2
# ELO for White: 852.5227927437827 ELO for Black: 1147.4772072562173
# The Winner is: Black
# Decisive Move: f6e4
# ELO for White: 831.3913054580843 ELO for Black: 1168.6086945419158
# The Winner is: Black
# Decisive Move: b5d4
# ELO for White: 809.529264248668 ELO for Black: 1190.470735751332
# The Winner is: Black
# Decisive Move: f5e3
# ELO for White: 787.0390669718811 ELO for Black: 1212.960933028119
# The Winner is: Black
# Decisive Move: b5e2
# ELO for White: 764.0217363154541 ELO for Black: 1235.978263684546
# The Winner is: Black
# Decisive Move: g5c1
# ELO for White: 740.5714679512954 ELO for Black: 1259.4285320487047
# The Winner is: Black
# Decisive Move: f6f2
# ELO for White: 716.7721337698905 ELO for Black: 1283.2278662301096
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: 692.6956688362354 ELO for Black: 1307.3043311637648
# The Winner is: Black
# Decisive Move: e7e2
# ELO for White: 668.401941657656 ELO for Black: 1331.5980583423443
# The Winner is: Black
# Decisive Move: f4f1
# ELO for White: 643.9396016318306 ELO for Black: 1356.06039836817
# The Winner is: Black
# Decisive Move: e4e1
# ELO for White: 619.3474461266981 ELO for Black: 1380.6525538733024
# The Winner is: Black
# Decisive Move: g1h2
# ELO for White: 594.655966849471 ELO for Black: 1405.3440331505294
# The Winner is: Black
# Decisive Move: d5g2
# ELO for White: 569.8888591478882 ELO for Black: 1430.1111408521122
# The Winner is: Black
# Decisive Move: b6a6
# ELO for White: 545.0643782832938 ELO for Black: 1454.9356217167065
# The Winner is: Black
# Decisive Move: f8a3
# ELO for White: 520.196495889493 ELO for Black: 1479.8035041105072
# The Winner is: Black
# Decisive Move: d2d1q
# ELO for White: 495.29585165250023 ELO for Black: 1504.7041483475
# The Winner is: Black
# Decisive Move: e1e4
# Elapsed time: 2:27:15.17
# 1st Quarter Winner: Black
# Board('r3kbn1/1p1b1p2/2n3r1/3pPp1p/pP2q3/5K2/5P1P/8 w q - 4 26')

# %%
White = Agent(isWhite=True)
Black = Greedy(isWhite=False)

Game = Environement(White, Black)
start_time = time.time()
Game.Training(25)

elapsed_time = time.time() - start_time
print("Elapsed time: {}".format(hms_string(elapsed_time)))
print("2nd Quarter Winner: {}".format(Game.Winner))
Game.board
# Out:
# ELO for White: 1000 ELO for Black: 1000
# The Winner is: Black
# Decisive Move: d2d1q
# ELO for White: 987.5 ELO for Black: 1012.5
# The Winner is: Black
# Decisive Move: d5h1
# ELO for White: 974.1021018263724 ELO for Black: 1025.8978981736275
# The Winner is: Black
# Decisive Move: c6f3
# ELO for White: 959.752282032871 ELO for Black: 1040.247717967129
# The Winner is: Black
# Decisive Move: d6h2
# ELO for White: 944.4069548774982 ELO for Black: 1055.5930451225017
# The Winner is: Black
# Decisive Move: a5d2
# ELO for White: 928.0379003095996 ELO for Black: 1071.9620996904002
# The Winner is: Black
# Decisive Move: f2g1
# ELO for White: 910.6369887777504 ELO for Black: 1089.3630112222495
# Stalemate Due to Repetition
# ELO for White: 904.71976519151 ELO for Black: 1095.28023480849
# The Winner is: Black
# Decisive Move: d4d1
# ELO for White: 885.9775405081565 ELO for Black: 1114.0224594918434
# The Winner is: Black
# Decisive Move: d8d5
# ELO for White: 866.278291203643 ELO for Black: 1133.7217087963568
# The Winner is: Black
# Decisive Move: d2d1q
# ELO for White: 845.6933884663035 ELO for Black: 1154.3066115336962
# The Winner is: Black
# Decisive Move: d7a4
# ELO for White: 824.3117212581724 ELO for Black: 1175.6882787418274
# The Winner is: Black
# Decisive Move: e1d1
# ELO for White: 802.232759564249 ELO for Black: 1197.7672404357509
# The Winner is: Black
# Decisive Move: e5e2
# ELO for White: 779.5591590266043 ELO for Black: 1220.4408409733956
# The Winner is: Black
# Decisive Move: c2e2
# ELO for White: 756.3902166218401 ELO for Black: 1243.6097833781598
# The Winner is: Black
# Decisive Move: e4e1
# ELO for White: 732.8170368300509 ELO for Black: 1267.182963169949
# The Winner is: Black
# Decisive Move: c3c2
# ELO for White: 708.9196801477502 ELO for Black: 1291.0803198522497
# The Winner is: Black
# Decisive Move: d5e3
# ELO for White: 684.7660888391159 ELO for Black: 1315.233911160884
# The Winner is: Black
# Decisive Move: c4d3
# ELO for White: 660.4123326518002 ELO for Black: 1339.5876673481996
# The Winner is: Black
# Decisive Move: d4f5
# ELO for White: 635.9036716633636 ELO for Black: 1364.0963283366361
# The Winner is: Black
# Decisive Move: a4b4
# ELO for White: 611.2760131947185 ELO for Black: 1388.7239868052811
# The Winner is: Black
# Decisive Move: a4b4
# ELO for White: 586.5574643508266 ELO for Black: 1413.4425356491731
# The Winner is: Black
# Decisive Move: g2e4
# ELO for White: 561.7698000068951 ELO for Black: 1438.2301999931046
# The Winner is: Black
# Decisive Move: d3d2
# ELO for White: 536.929756309018 ELO for Black: 1463.0702436909817
# The Winner is: Black
# Decisive Move: h4f2
# ELO for White: 512.0501192586346 ELO for Black: 1487.9498807413652
# The Winner is: Black
# Decisive Move: b6b2
# Elapsed time: 1:55:59.08
# 2nd Quarter Winner: Black
# Board('r1b1k2r/pp1n1pp1/4p3/8/P2PppP1/b1p5/1qP3nP/K5R1 w kq - 4 20')

# %%
White = Agent(isWhite=True)
Black = Greedy(isWhite=False)

Game = Environement(White, Black)
start_time = time.time()
Game.Training(25)

elapsed_time = time.time() - start_time
print("Elapsed time: {}".format(hms_string(elapsed_time)))
print("3rd Quarter Winner: {}".format(Game.Winner))
Game.board
# Out:
# ELO for White: 1000 ELO for Black: 1000
# The Winner is: Black
# Decisive Move: c8g4
# ELO for White: 987.5 ELO for Black: 1012.5
# The Winner is: Black
# Decisive Move: d1d3
# ELO for White: 974.1021018263724 ELO for Black: 1025.8978981736275
# The Winner is: Black
# Decisive Move: e1d1
# ELO for White: 959.752282032871 ELO for Black: 1040.247717967129
# The Winner is: Black
# Decisive Move: d6b4
# ELO for White: 944.4069548774982 ELO for Black: 1055.5930451225017
# The Winner is: Black
# Decisive Move: d2c2
# ELO for White: 928.0379003095996 ELO for Black: 1071.9620996904002
# The Winner is: Black
# Decisive Move: e1d1
# ELO for White: 910.6369887777504 ELO for Black: 1089.3630112222495
# The Winner is: Black
# Decisive Move: h4f2
# ELO for White: 892.21976519151 ELO for Black: 1107.78023480849
# The Winner is: Black
# Decisive Move: d4e3
# ELO for White: 872.8268980648905 ELO for Black: 1127.1731019351093
# The Winner is: Black
# Decisive Move: h4e1
# ELO for White: 852.5227927437827 ELO for Black: 1147.4772072562173
# The Winner is: Black
# Decisive Move: d8d1
# ELO for White: 831.3913054580843 ELO for Black: 1168.6086945419158
# The Winner is: Black
# Decisive Move: e7e1
# ELO for White: 809.529264248668 ELO for Black: 1190.470735751332
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: 787.0390669718811 ELO for Black: 1212.960933028119
# The Winner is: Black
# Decisive Move: f2e1
# ELO for White: 764.0217363154541 ELO for Black: 1235.978263684546
# The Winner is: Black
# Decisive Move: e2h2
# ELO for White: 740.5714679512954 ELO for Black: 1259.4285320487047
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: 716.7721337698905 ELO for Black: 1283.2278662301096
# The Winner is: Black
# Decisive Move: d8d3
# ELO for White: 692.6956688362354 ELO for Black: 1307.3043311637648
# The Winner is: Black
# Decisive Move: e5a1
# ELO for White: 668.401941657656 ELO for Black: 1331.5980583423443
# The Winner is: Black
# Decisive Move: d4b3
# ELO for White: 643.9396016318306 ELO for Black: 1356.06039836817
# The Winner is: Black
# Decisive Move: e5b2
# ELO for White: 619.3474461266981 ELO for Black: 1380.6525538733024
# The Winner is: Black
# Decisive Move: g2c2
# ELO for White: 594.655966849471 ELO for Black: 1405.3440331505294
# The Winner is: Black
# Decisive Move: c8f5
# ELO for White: 569.8888591478882 ELO for Black: 1430.1111408521122
# The Winner is: Black
# Decisive Move: h4e4
# ELO for White: 545.0643782832938 ELO for Black: 1454.9356217167065
# The Winner is: Black
# Decisive Move: h1h2
# ELO for White: 520.196495889493 ELO for Black: 1479.8035041105072
# The Winner is: Black
# Decisive Move: f1d3
# ELO for White: 495.29585165250023 ELO for Black: 1504.7041483475
# The Winner is: Black
# Decisive Move: g1f1
# Elapsed time: 1:56:21.23
# 3rd Quarter Winner: Black
# Board('r1b1k2r/pp2npp1/P3p3/4PP1P/1n1p2p1/2p3P1/3b4/R1BK1q2 w kq - 0 18')

# %%
White = Agent(isWhite=True)
Black = Greedy(isWhite=False)

Game = Environement(White, Black)
start_time = time.time()
Game.Training(25)

elapsed_time = time.time() - start_time
print("Elapsed time: {}".format(hms_string(elapsed_time)))
print("Final Winner: {}".format(Game.Winner))
Game.board
# Out:
# ELO for White: 1000 ELO for Black: 1000
# The Winner is: Black
# Decisive Move: d1f1
# ELO for White: 987.5 ELO for Black: 1012.5
# The Winner is: Black
# Decisive Move: g2c2
# ELO for White: 974.1021018263724 ELO for Black: 1025.8978981736275
# The Winner is: Black
# Decisive Move: b4c2
# ELO for White: 959.752282032871 ELO for Black: 1040.247717967129
# Stalemate Due to Repetition
# ELO for White: 956.9069548774982 ELO for Black: 1043.0930451225017
# The Winner is: White
# Decisive Move: a1c2
# ELO for White: 966.3682365031805 ELO for Black: 1033.6317634968195
# The Winner is: Black
# Decisive Move: c2g6
# ELO for White: 951.478024710731 ELO for Black: 1048.521975289269
# The Winner is: Black
# Decisive Move: c1e3
# ELO for White: 935.5746381392491 ELO for Black: 1064.4253618607509
# The Winner is: Black
# Decisive Move: f5e3
# ELO for White: 918.6403177011597 ELO for Black: 1081.3596822988402
# The Winner is: Black
# Decisive Move: d8h4
# ELO for White: 900.6795638217937 ELO for Black: 1099.3204361782061
# The Winner is: Black
# Decisive Move: e4c3
# ELO for White: 881.7216652819855 ELO for Black: 1118.2783347180145
# The Winner is: Black
# Decisive Move: h5f3
# ELO for White: 861.8206485910479 ELO for Black: 1138.1793514089522
# The Winner is: Black
# Decisive Move: b1d1
# ELO for White: 841.0522621428408 ELO for Black: 1158.9477378571592
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: 819.50835758409 ELO for Black: 1180.49164241591
# The Winner is: Black
# Decisive Move: c8e6
# ELO for White: 797.2897292845097 ELO for Black: 1202.7102707154904
# The Winner is: Black
# Decisive Move: c1e3
# ELO for White: 774.4988049225125 ELO for Black: 1225.5011950774876
# The Winner is: Black
# Decisive Move: d1c2
# ELO for White: 751.2334242740388 ELO for Black: 1248.7665757259613
# The Winner is: Black
# Decisive Move: d4f2
# ELO for White: 727.5824380260212 ELO for Black: 1272.417561973979
# The Winner is: Black
# Decisive Move: d7b5
# ELO for White: 703.6232775755411 ELO for Black: 1296.376722424459
# The Winner is: Black
# Decisive Move: g5d2
# ELO for White: 679.4212148804002 ELO for Black: 1320.5787851196
# The Winner is: Black
# Decisive Move: d5f3
# ELO for White: 655.029829721585 ELO for Black: 1344.9701702784153
# The Winner is: Black
# Decisive Move: e4f3
# ELO for White: 630.4921914812967 ELO for Black: 1369.5078085187035
# The Winner is: Black
# Decisive Move: b3c2
# ELO for White: 605.8423582613148 ELO for Black: 1394.1576417386855
# The Winner is: Black
# Decisive Move: c1e3
# ELO for White: 581.1069226308115 ELO for Black: 1418.8930773691886
# The Winner is: Black
# Decisive Move: d1c2
# ELO for White: 556.3064463968817 ELO for Black: 1443.6935536031185
# The Winner is: Black
# Decisive Move: c1e3
# Elapsed time: 2:01:24.70
# Final Winner: Black
# Board('rn2kb1r/ppp2ppp/8/P7/1n1p4/1b2q2P/4K3/RN3BNR w kq - 2 17')
